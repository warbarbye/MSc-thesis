# %%
library(tidyverse)
library(magrittr)
library(latex2exp)
library(gridExtra)
library(scales)
library(cowplot)
source("../src/cma-es-csa.R")
source("../src/cma-es-msr.R")
source("../src/cma-es-expth.R")
source("../src/cma-es-ja.R")
source("../src/cma-es-quant.R")
options(repr.plot.width=10, repr.plot.height=10)
source("`../src/plot-utils.R")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.1     ✔ purrr   0.3.4
# ✔ tibble  3.0.1     ✔ dplyr   1.0.0
# ✔ tidyr   1.0.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘magrittr’
#
#
# The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# The following object is masked from ‘package:tidyr’:
#
#     extract
#
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
#
# Attaching package: ‘scales’
#
#
# The following object is masked from ‘package:purrr’:
#
#     discard
#
#
# The following object is masked from ‘package:readr’:
#
#     col_factor
#
#
#
# ********************************************************
#
# Note: As of version 1.0.0, cowplot does not change the
#
#   default ggplot2 theme anymore. To recover the previous
#
#   behavior, execute:
#   theme_set(theme_cowplot())
#
# ********************************************************

# %%
func = function(x) x[1]
methods = list(
    cma_es_csa,
    cma_es_ja,
    cma_es_msr,
    cma_es_expth,
    cma_es_quant)

lower = -100
upper = 100 
x0 = 100
CMA_flag = TRUE
alog10 = . %>% abs() %>% log10()

# %%
results_5d = 
    do_experiment(
        methods,
        func,
        5,
        x0,
        lower = lower,
        upper = upper,
        if_CMA = CMA_flag
    ) %>%
    rename_algs() %>%
    dplyr::mutate(Dim = 5)

# %%
results_10d = 
    do_experiment(
        methods,
        func,
        10,
        x0,
        lower = lower,
        upper = upper,
        if_CMA = CMA_flag
    ) %>%
    rename_algs()  %>%
    dplyr::mutate(Dim = 10)

# %%
results_30d = 
    do_experiment(
        methods,
        func,
        30,
        x0,
        lower = lower,
        upper = upper,
        if_CMA = CMA_flag
    ) %>%
    rename_algs()  %>%
    dplyr::mutate(Dim = 30)

# %%
results_50d = 
    do_experiment(
        methods,
        func,
        50,
        x0,
        lower = lower,
        upper = upper,
        if_CMA = CMA_flag
    ) %>%
    rename_algs() %>%
    dplyr::mutate(Dim = 50)

# %%
all_results = 
    dplyr::bind_rows(results_5d, results_10d, results_30d, results_50d)

# %%
p_d5 = 
    all_results %>%
    dplyr::filter(Dim == 5) %>%
    sigma_plot() + theme(legend.position =  'none') + ggtitle("n = 5")
p_d10 = 
    all_results %>%
    dplyr::filter(Dim == 10) %>%
    sigma_plot() + 
    theme(legend.position =  c(0.3, 0.75)) +
    ggtitle("n = 10") +
    ylab("")
p_d30 = 
    all_results %>%
    dplyr::filter(Dim == 30, t <= 150) %>%
    sigma_plot() + theme(legend.position = "none") + ggtitle("n = 30")
p_d50 = 
    all_results %>%
    dplyr::filter(Dim == 50, t <= 150) %>%
    sigma_plot() + 
    theme(legend.position = "none") +
    ggtitle("n = 50") +
    ylab("")

# %%
plot_grid(p_d5, p_d10, p_d30, p_d50)
# Out:
# plot without title

# %%
best_d5 = 
    all_results %>%
    dplyr::filter(Dim == 5) %>%
    value_plot(.f = alog10) + theme(legend.position =  'none') + ggtitle("n = 5")
best_d10 = 
    all_results %>%
    dplyr::filter(Dim == 10) %>%
    value_plot(.f = alog10) + 
    theme(legend.position =  c(0.70, 0.3)) +
    ggtitle("n = 10") +
    ylab("")
best_d30 = 
    all_results %>%
    dplyr::filter(Dim == 30, t <= 150) %>%
    value_plot(.f = alog10) + theme(legend.position = "none") + ggtitle("n = 30")
best_d50 = 
    all_results %>%
    dplyr::filter(Dim == 50, t <= 150) %>%
    value_plot(.f = alog10) + 
    theme(legend.position = "none") +
    ggtitle("n = 50") +
    ylab("")

# %%
plot_grid(best_d5, best_d10, best_d30, best_d50)
# Out:
# Warning message in self$trans$transform(x):
# “NaNs produced”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message in self$trans$transform(x):
# “NaNs produced”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Removed 2 rows containing missing values (geom_point).”
# plot without title
